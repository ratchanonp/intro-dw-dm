# %%
import pandas as pd

# %%
data_source_1_path = "./sources/ETLDataSource1.xlsx"
data_source_2_path = "./sources/ETLDataSource2.xlsx"

# %% [markdown]
# # Load Data

# %%
orderSource1 = pd.read_excel(data_source_1_path, sheet_name="orderSource1")
productSource1 = pd.read_excel(data_source_1_path, sheet_name="productSource1")

orderSource2 = pd.read_excel(data_source_2_path, sheet_name="orderSource2")
productSource2 = pd.read_excel(data_source_2_path, sheet_name="productSource2")

stateLookUp = pd.read_excel(data_source_1_path, sheet_name="StateLookup")

# %% [markdown]
# # Transform Source 1

# %%
# Join order and product with OrderID
data_source_1 = pd.merge(orderSource1, productSource1, on="OrderID", how="inner")

# Replace Dictionary
state_dict = dict(zip(stateLookUp["Abbreviation"], stateLookUp["State"]))
data_source_1 = data_source_1.replace({"CustomerState": state_dict})

# Split CustomerName
# Rename CustomerName[0] to CustomerFirstName and CustomerName[0] to CustomerLastName
data_source_1[['CustomerFirstName','CustomerLastName']] = data_source_1["CustomerName"].str.split(" ", n = 1, expand = True)

data_source_1 = data_source_1.drop(columns=["CustomerName"])

# Reorder Attributes alphabetically ascending
data_source_1 = data_source_1.reindex(sorted(data_source_1.columns), axis=1)

# %% [markdown]
# # Transform Source 2

# %%
data_source_2 = pd.merge(orderSource2, productSource2, on="OrderID", how="inner")

# Replace OrderID prefix A with ""
data_source_2["OrderID"] = data_source_2["OrderID"].str.replace("A", "")

# Parse OrderId to int
data_source_2["OrderID"] = data_source_2["OrderID"].astype(int)

# Change CustomerStatus type to polynomial
data_source_2["CustomerStatus"] = data_source_2["CustomerStatus"].astype("category").cat.codes

CustomerStatus_map = {
    0: "Silver",
    1: "Gold",
    2: "Platinum"
}

# Replace CustomerStatus with map
data_source_2["CustomerStatus"] = data_source_2["CustomerStatus"].replace(CustomerStatus_map)

# Remove totalDiscount column
data_source_2 = data_source_2.drop(columns=["TotalDiscount"])

# Generate new column TotalDiscount
data_source_2["TotalDiscount"] = data_source_2["FullPrice"] - data_source_2["ExtendedPrice"]

# Reorder Attributes alphabetically ascending
data_source_2 = data_source_2.reindex(sorted(data_source_2.columns), axis=1)

# %% [markdown]
# # Append and write to Excel

# %%
data_source = pd.concat([data_source_1, data_source_2], ignore_index=True)

# Generate concatenated column customerName from CustomerFirstName and CustomerLastName
data_source["customerName"] = data_source["CustomerFirstName"] + "_" + data_source["CustomerLastName"]

# Remove CustomerFirstName and CustomerLastName
data_source = data_source.drop(columns=["CustomerFirstName", "CustomerLastName"])

# Reorder Attributes alphabetically ascending
data_source = data_source.reindex(sorted(data_source.columns), axis=1)

# Write to Excel
data_source.to_excel("./Result_Python.xlsx", index=False)

data_source
# Out:
#       CustomerCity     CustomerState CustomerStatus  Discount  ExtendedPrice  \
# 0       Pittsburgh      Pennsylvania         Silver      0.00         168.00
# 1       Pittsburgh      Pennsylvania         Silver      0.00          98.00
# 2       Pittsburgh      Pennsylvania         Silver      0.00         174.00
# 3            Miami           Florida       Platinum      0.00        1696.00
# 4            Miami           Florida       Platinum      0.00         167.40
# 5     Philadelphia      Pennsylvania       Platinum      0.15        1261.40
# 6     Philadelphia      Pennsylvania       Platinum      0.00          77.00
# 7     Philadelphia      Pennsylvania       Platinum      0.15         214.20
# 8           Tacoma        Washington       Platinum      0.00         336.00
# 9           Tacoma        Washington       Platinum      0.05          95.76
# 10          Tacoma        Washington       Platinum      0.05         222.30
# 11    Philadelphia      Pennsylvania       Platinum      0.05          47.50
# 12    Philadelphia      Pennsylvania       Platinum      0.05        2462.40
# 13    Philadelphia      Pennsylvania       Platinum      0.00        1088.00
# 14    Philadelphia      Pennsylvania       Platinum      0.00         640.00
# 15    Philadelphia      Pennsylvania       Platinum      0.00         604.80
# 16    Philadelphia      Pennsylvania       Platinum      0.00         200.00
# 17      Pittsburgh      Pennsylvania           Gold      0.15         342.72
# 18      Pittsburgh      Pennsylvania           Gold      0.00         168.00
# 19      Pittsburgh      Pennsylvania           Gold      0.15          45.90
# 20          Tacoma        Washington           Gold      0.00         380.00
# 21          Tacoma        Washington           Gold      0.00        1320.00
# 22          Tacoma        Washington           Gold      0.00         486.50
# 23          Tacoma        Washington           Gold      0.00         304.00
# 24  Salt Lake City              Utah         Silver      0.15         393.00
# 25  Salt Lake City              Utah         Silver      0.00         124.80
# 26      Charleston    South Carolina         Silver      0.00         877.50
# 27      Charleston    South Carolina         Silver      0.00          86.40
# 28      Charleston    South Carolina         Silver      0.00         156.00
# 29     Kansas City            Kansas           Gold      0.20         608.00
# 30     Kansas City            Kansas           Gold      0.20         122.88
# 31     Kansas City            Kansas           Gold      0.20         884.00
# 32      Greensboro    North Carolina       Platinum      0.00          80.00
# 33      Greensboro    North Carolina       Platinum      0.00          20.80
# 34        Colombus              Ohio       Platinum      0.25         189.00
# 35        Colombus              Ohio       Platinum      0.00         780.00
# 36        Colombus              Ohio       Platinum      0.25         443.25
# 37        Colombus              Ohio       Platinum      0.25          92.40
# 38         Detroit          Michigan         Silver      0.00         288.00
# 39         Detroit          Michigan         Silver      0.00         160.00
# 40        Colombus              Ohio           Gold      0.20         163.20
# 41        Colombus              Ohio           Gold      0.00         360.00
# 42        Colombus              Ohio           Gold      0.00          60.80
# 43           Provo              Utah           Gold      0.25         625.50
# 44           Provo              Utah           Gold      0.25         931.50
# 45           Provo              Utah           Gold      0.25         216.00
# 46           Provo              Utah           Gold      0.00         100.80
# 47    Philadelphia      Pennsylvania           Gold      0.00         532.00
# 48    Philadelphia      Pennsylvania           Gold      0.15         163.62
# 49     Kansas City          Missouri           Gold      0.00         936.00
# 50     Kansas City          Missouri           Gold      0.00         240.00
# 51         Seattle        Washington       Platinum      0.05         346.56
# 52         Toronto           Ontario         Silver      0.15         183.60
# 53         Toronto           Ontario         Silver      0.00         735.00
# 54         Toronto           Ontario         Silver      0.15        2618.00
# 55      Providence      Rhode Island           Gold      0.00         990.00
# 56      Providence      Rhode Island           Gold      0.00         111.20
# 57        Vancover  British Columbia       Platinum      0.05         528.20
# 58        Vancover  British Columbia       Platinum      0.05         114.00
#
#     FullPrice  OrderDate  OrderID                           Product  \
# 0       168.0 2011-01-11    10248                    Queso Cabrales
# 1        98.0 2011-01-11    10248     Singaporean Hokkien Fried Mee
# 2       174.0 2011-01-11    10248            Mozzarella di Giovanni
# 3      1696.0 2011-01-11    10249             Manjimup Dried Apples
# 4       167.4 2011-01-11    10249                              Tofu
# 5      1484.0 2011-01-11    10250             Manjimup Dried Apples
# 6        77.0 2011-01-11    10250   Jack's New England Clam Chowder
# 7       252.0 2011-01-11    10250  Louisiana Fiery Hot Pepper Sauce
# 8       336.0 2011-01-11    10251  Louisiana Fiery Hot Pepper Sauce
# 9       100.8 2011-01-11    10251               Gustaf's Knäckebröd
# 10      234.0 2011-01-11    10251                    Ravioli Angelo
# 11       50.0 2011-01-11    10252                           Geitost
# 12     2592.0 2011-01-11    10252            Sir Rodney's Marmalade
# 13     1088.0 2011-01-11    10252                 Camembert Pierrot
# 14      640.0 2011-01-11    10253                          Maxilaku
# 15      604.8 2011-01-11    10253                  Chartreuse verte
# 16      200.0 2011-01-11    10253                 Gorgonzola Telino
# 17      403.2 2011-01-11    10254                      Pâté chinois
# 18      168.0 2011-01-11    10254                     Longlife Tofu
# 19       54.0 2011-01-11    10254                Guaraná Fantástica
# 20      380.0 2011-01-11    10255                       Inlagd Sill
# 21     1320.0 2011-01-11    10255              Raclette Courdavault
# 22      486.5 2011-01-11    10255                           Pavlova
# 23      304.0 2011-01-11    10255                             Chang
# 24      393.0 2011-01-11    10256                     Perth Pasties
# 25      124.8 2011-01-11    10256   Original Frankfurter grüne Soße
# 26      877.5 2011-01-11    10257                Schoggi Schokolade
# 27       86.4 2011-01-11    10257                  Chartreuse verte
# 28      156.0 2011-01-11    10257   Original Frankfurter grüne Soße
# 29      760.0 2011-01-11    10258                             Chang
# 30      153.6 2011-01-11    10258                Mascarpone Fabioli
# 31     1105.0 2011-01-11    10258            Chef Anton's Gumbo Mix
# 32       80.0 2011-01-11    10259               Sir Rodney's Scones
# 33       20.8 2011-01-11    10259                        Gravad lax
# 34      252.0 2011-01-11    10260                     Outback Lager
# 35      780.0 2011-01-11    10260                    Ravioli Angelo
# 36      591.0 2011-01-11    10260                    Tarte au sucre
# 37      123.2 2011-01-11    10260   Jack's New England Clam Chowder
# 38      288.0 2011-01-11    10261                    Steeleye Stout
# 39      160.0 2011-01-11    10261               Sir Rodney's Scones
# 40      204.0 2011-01-11    10262            Chef Anton's Gumbo Mix
# 41      360.0 2011-01-11    10262   Uncle Bob's Organic Dried Pears
# 42       60.8 2011-01-11    10262            Gnocchi di nonna Alice
# 43      834.0 2011-01-11    10263                           Pavlova
# 44     1242.0 2011-01-11    10263             Nord-Ost Matjeshering
# 45      288.0 2011-01-11    10263                     Longlife Tofu
# 46      100.8 2011-01-11    10263                Guaraná Fantástica
# 47      532.0 2011-01-11    10264                             Chang
# 48      192.5 2011-01-11    10264   Jack's New England Clam Chowder
# 49      936.0 2011-01-11    10265                      Alice Mutton
# 50      240.0 2011-01-11    10265                     Outback Lager
# 51      364.8 2011-01-11    10266         Queso Manchego La Pastora
# 52      216.0 2011-01-11    10267                      Lakkalikööri
# 53      735.0 2011-01-11    10267                  Boston Crab Meat
# 54     3080.0 2011-01-11    10267              Raclette Courdavault
# 55      990.0 2011-01-11    10268           Thüringer Rostbratwurst
# 56      111.2 2011-01-11    10268            Mozzarella di Giovanni
# 57      556.0 2011-01-11    10269            Mozzarella di Giovanni
# 58      120.0 2011-01-11    10269                           Geitost
#
#     ProductID  Quantity  TotalDiscount  UnitPrice          customerName
# 0          11        12           0.00       14.0           Suzan_Plock
# 1          42        10           0.00        9.8           Suzan_Plock
# 2          72         5           0.00       34.8           Suzan_Plock
# 3          51        40           0.00       42.4          Allan_Strate
# 4          14         9           0.00       18.6          Allan_Strate
# 5          51        35         222.60       42.4       Elnora_Willison
# 6          41        10           0.00        7.7       Elnora_Willison
# 7          65        15          37.80       16.8       Elnora_Willison
# 8          65        20           0.00       16.8      Daniela_Becknell
# 9          22         6           5.04       16.8      Daniela_Becknell
# 10         57        15          11.70       15.6      Daniela_Becknell
# 11         33        25           2.50        2.0    Cathrine_Delamater
# 12         20        40         129.60       64.8    Cathrine_Delamater
# 13         60        40           0.00       27.2    Cathrine_Delamater
# 14         49        40           0.00       16.0     Leota_Vonderheide
# 15         39        42           0.00       14.4     Leota_Vonderheide
# 16         31        20           0.00       10.0     Leota_Vonderheide
# 17         55        21          60.48       19.2           Tyrone_Hine
# 18         74        21           0.00        8.0           Tyrone_Hine
# 19         24        15           8.10        3.6           Tyrone_Hine
# 20         36        25           0.00       15.2  Christin_Tillinghast
# 21         59        30           0.00       44.0  Christin_Tillinghast
# 22         16        35           0.00       13.9  Christin_Tillinghast
# 23          2        20           0.00       15.2  Christin_Tillinghast
# 24         53        15           0.00       26.2          Kisha_Grauer
# 25         77        12           0.00       10.4          Kisha_Grauer
# 26         27        25           0.00       35.1      Darryl_Manuelito
# 27         39         6           0.00       14.4      Darryl_Manuelito
# 28         77        15           0.00       10.4      Darryl_Manuelito
# 29          2        50         152.00       15.2   Milagros_Fehrenbach
# 30         32         6          30.72       25.6   Milagros_Fehrenbach
# 31          5        65         221.00       17.0   Milagros_Fehrenbach
# 32         21        10           0.00        8.0         Julio_Willard
# 33         37         1           0.00       20.8         Julio_Willard
# 34         70        21          63.00       12.0          Roslyn_Plott
# 35         57        50           0.00       15.6          Roslyn_Plott
# 36         62        15         147.75       39.4          Roslyn_Plott
# 37         41        16          30.80        7.7          Roslyn_Plott
# 38         35        20           0.00       14.4              Eve_Haak
# 39         21        20           0.00        8.0              Eve_Haak
# 40          5        12          40.80       17.0            Max_Kindle
# 41          7        15           0.00       24.0            Max_Kindle
# 42         56         2           0.00       30.4            Max_Kindle
# 43         16        60         208.50       13.9         Roxie_Prewitt
# 44         30        60         310.50       20.7         Roxie_Prewitt
# 45         74        36          72.00        8.0         Roxie_Prewitt
# 46         24        28           0.00        3.6         Roxie_Prewitt
# 47          2        35           0.00       15.2             Erik_Vire
# 48         41        25          28.88        7.7             Erik_Vire
# 49         17        30           0.00       31.2           Lonnie_Ludy
# 50         70        20           0.00       12.0           Lonnie_Ludy
# 51         12        12          18.24       30.4      Jamie_Woodbridge
# 52         76        15          32.40       14.4        Eleanor_Aburto
# 53         40        50           0.00       14.7        Eleanor_Aburto
# 54         59        70         462.00       44.0        Eleanor_Aburto
# 55         29        10           0.00       99.0          Odessa_Smith
# 56         72         4           0.00       27.8          Odessa_Smith
# 57         72        20          27.80       27.8           Jamie_Sabat
# 58         33        60           6.00        2.0           Jamie_Sabat
